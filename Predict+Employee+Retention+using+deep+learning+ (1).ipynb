# %% [markdown]
# # Import libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np

src_path = "/content/drive/MyDrive/Deep Learning My practicals/EmployeeDataSet"
sub_class = os.listdir(src_path)

# Assuming you have a CSV file within the specified directory
csv_file_path = os.path.join(src_path, "hr.csv")
df = pd.read_csv(csv_file_path)

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
#convert categorical to numeric values
feats=['department','salary']
df_final=pd.get_dummies(df,columns=feats,drop_first=True)

# %%
df_final
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years  department_RandD  department_accounting  \
# 0                          0                 0                      0
# 1                          0                 0                      0
# 2                          0                 0                      0
# 3                          0                 0                      0
# 4                          0                 0                      0
# ...                      ...               ...                    ...
# 14994                      0                 0                      0
# 14995                      0                 0                      0
# 14996                      0                 0                      0
# 14997                      0                 0                      0
# 14998                      0                 0                      0
#
#        department_hr  department_management  department_marketing  \
# 0                  0                      0                     0
# 1                  0                      0                     0
# 2                  0                      0                     0
# 3                  0                      0                     0
# 4                  0                      0                     0
# ...              ...                    ...                   ...
# 14994              0                      0                     0
# 14995              0                      0                     0
# 14996              0                      0                     0
# 14997              0                      0                     0
# 14998              0                      0                     0
#
#        department_product_mng  department_sales  department_support  \
# 0                           0                 1                   0
# 1                           0                 1                   0
# 2                           0                 1                   0
# 3                           0                 1                   0
# 4                           0                 1                   0
# ...                       ...               ...                 ...
# 14994                       0                 0                   1
# 14995                       0                 0                   1
# 14996                       0                 0                   1
# 14997                       0                 0                   1
# 14998                       0                 0                   1
#
#        department_technical  salary_low  salary_medium
# 0                         0           1              0
# 1                         0           0              1
# 2                         0           0              1
# 3                         0           1              0
# 4                         0           1              0
# ...                     ...         ...            ...
# 14994                     0           1              0
# 14995                     0           1              0
# 14996                     0           1              0
# 14997                     0           1              0
# 14998                     0           1              0
#
# [14999 rows x 19 columns]

# %%
#Split data into training and test set
from sklearn.model_selection import train_test_split
X=df_final.drop(['left'],axis=1).values
y=df_final['left'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %% [markdown]
# # Transforming the data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# #  Build the artificial neural network

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier=Sequential()

# %%
classifier.add(Dense(9, kernel_initializer = "uniform",activation = "relu", input_dim=18))

# %%
classifier.add(Dense(1, kernel_initializer = "uniform",activation = "sigmoid"))

# %%
classifier.compile(optimizer= "adam",loss = "binary_crossentropy",metrics = ["accuracy"])

# %%
classifier.fit(X_train, y_train, batch_size = 10, epochs = 8)
# Out:
# Epoch 1/8
# 1125/1125 [==============================] - 3s 2ms/step - loss: 0.4184 - accuracy: 0.8194
# Epoch 2/8
# 1125/1125 [==============================] - 2s 2ms/step - loss: 0.2275 - accuracy: 0.9251
# Epoch 3/8
# 1125/1125 [==============================] - 2s 2ms/step - loss: 0.1833 - accuracy: 0.9444
# Epoch 4/8
# 1125/1125 [==============================] - 2s 2ms/step - loss: 0.1701 - accuracy: 0.9507
# Epoch 5/8
# 1125/1125 [==============================] - 2s 2ms/step - loss: 0.1644 - accuracy: 0.9514
# Epoch 6/8
# 1125/1125 [==============================] - 3s 2ms/step - loss: 0.1607 - accuracy: 0.9521
# Epoch 7/8
# 1125/1125 [==============================] - 2s 2ms/step - loss: 0.1582 - accuracy: 0.9542
# Epoch 8/8
# 1125/1125 [==============================] - 2s 2ms/step - loss: 0.1558 - accuracy: 0.9548

# %% [markdown]
# # Improving the Model Accuracy

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score

# %%
def make_classifier():
    classifier = Sequential()
    classifier.add(Dense(9, kernel_initializer = "uniform", activation = "relu", input_dim=18))
    classifier.add(Dense(1, kernel_initializer = "uniform", activation = "sigmoid"))
    classifier.compile(optimizer= "adam",loss = "binary_crossentropy",metrics = ["accuracy"])
    return classifier

# %%
classifier = KerasClassifier(build_fn = make_classifier, batch_size=10, nb_epoch=2)
# Out:
# <ipython-input-17-820a39cf0ef5>:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classifier = KerasClassifier(build_fn = make_classifier, batch_size=10, nb_epoch=2)

# %%
accuracies = cross_val_score(estimator = classifier,X = X_train,y = y_train,cv = 10,n_jobs = -1)

# %%
mean = accuracies.mean()
mean
# Out:
# 0.836246258020401

# %% [markdown]
# # Adding Dropout Regularization to Fight Over-Fitting

# %%
from keras.layers import Dropout

classifier = Sequential()
classifier.add(Dense(9, kernel_initializer = "uniform", activation = "relu", input_dim=18))
classifier.add(Dropout(rate = 0.1))
classifier.add(Dense(1, kernel_initializer = "uniform", activation = "sigmoid"))
classifier.compile(optimizer= "adam",loss = "binary_crossentropy",metrics = ["accuracy"])

# %%
from sklearn.model_selection import GridSearchCV
def make_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(9, kernel_initializer = "uniform", activation = "relu", input_dim=18))
    classifier.add(Dense(1, kernel_initializer = "uniform", activation = "sigmoid"))
    classifier.compile(optimizer= optimizer,loss = "binary_crossentropy",metrics = ["accuracy"])
    return classifier

# %%
classifier = KerasClassifier(build_fn = make_classifier)
# Out:
# <ipython-input-22-2e4efb2ecbd2>:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classifier = KerasClassifier(build_fn = make_classifier)

# %%
params = {
    'batch_size':[20,35],
    'epochs':[2,3],
    'optimizer':['adam','rmsprop']
}

# %%
grid_search = GridSearchCV(estimator=classifier,
                           param_grid=params,
                           scoring="accuracy",
                           cv=2)

# %%
grid_search = grid_search.fit(X_train,y_train)
# Out:
# Epoch 1/2
# 282/282 [==============================] - 2s 2ms/step - loss: 0.5616 - accuracy: 0.7624
# Epoch 2/2
# 282/282 [==============================] - 1s 2ms/step - loss: 0.3692 - accuracy: 0.8355
# 176/176 [==============================] - 0s 1ms/step
# Epoch 1/2
# 282/282 [==============================] - 1s 2ms/step - loss: 0.5788 - accuracy: 0.7600
# Epoch 2/2
# 282/282 [==============================] - 0s 2ms/step - loss: 0.3823 - accuracy: 0.8322
# 176/176 [==============================] - 0s 1ms/step
# Epoch 1/2
# 282/282 [==============================] - 1s 2ms/step - loss: 0.5793 - accuracy: 0.7672
# Epoch 2/2
# 282/282 [==============================] - 0s 2ms/step - loss: 0.4148 - accuracy: 0.7978
# 176/176 [==============================] - 0s 1ms/step
# Epoch 1/2
# 282/282 [==============================] - 1s 2ms/step - loss: 0.5799 - accuracy: 0.7612
# Epoch 2/2
# 282/282 [==============================] - 0s 2ms/step - loss: 0.4229 - accuracy: 0.7737
# 176/176 [==============================] - 0s 1ms/step
# Epoch 1/3
# 282/282 [==============================] - 1s 2ms/step - loss: 0.5778 - accuracy: 0.7651
# Epoch 2/3
# 282/282 [==============================] - 1s 2ms/step - loss: 0.4006 - accuracy: 0.8073
# Epoch 3/3
# 282/282 [==============================] - 1s 2ms/step - loss: 0.3389 - accuracy: 0.8318
# 176/176 [==============================] - 0s 2ms/step
# Epoch 1/3
# 282/282 [==============================] - 2s 2ms/step - loss: 0.5734 - accuracy: 0.7564
# Epoch 2/3
# 282/282 [==============================] - 1s 2ms/step - loss: 0.4207 - accuracy: 0.7612
# Epoch 3/3
# 282/282 [==============================] - 1s 2ms/step - loss: 0.3798 - accuracy: 0.7612
# 176/176 [==============================] - 0s 1ms/step
# Epoch 1/3
# 282/282 [==============================] - 1s 2ms/step - loss: 0.5751 - accuracy: 0.7664
# Epoch 2/3
# 282/282 [==============================] - 0s 2ms/step - loss: 0.4058 - accuracy: 0.7943
# Epoch 3/3
# 282/282 [==============================] - 0s 2ms/step - loss: 0.3359 - accuracy: 0.8466
# 176/176 [==============================] - 0s 1ms/step
# Epoch 1/3
# 282/282 [==============================] - 1s 2ms/step - loss: 0.5942 - accuracy: 0.7621
# Epoch 2/3
# 282/282 [==============================] - 0s 2ms/step - loss: 0.4277 - accuracy: 0.8055
# Epoch 3/3
# 282/282 [==============================] - 0s 2ms/step - loss: 0.3644 - accuracy: 0.8016
# 176/176 [==============================] - 0s 1ms/step
# Epoch 1/2
# 161/161 [==============================] - 1s 2ms/step - loss: 0.6310 - accuracy: 0.7585
# Epoch 2/2
# 161/161 [==============================] - 0s 2ms/step - loss: 0.4679 - accuracy: 0.7772
# 176/176 [==============================] - 0s 1ms/step
# Epoch 1/2
# 161/161 [==============================] - 1s 2ms/step - loss: 0.6325 - accuracy: 0.7536
# Epoch 2/2
# 161/161 [==============================] - 0s 2ms/step - loss: 0.4720 - accuracy: 0.8007
# 176/176 [==============================] - 0s 2ms/step
# Epoch 1/2
# 161/161 [==============================] - 1s 2ms/step - loss: 0.6413 - accuracy: 0.7621
# Epoch 2/2
# 161/161 [==============================] - 0s 2ms/step - loss: 0.5103 - accuracy: 0.8049
# 176/176 [==============================] - 0s 2ms/step
# Epoch 1/2
# 161/161 [==============================] - 1s 2ms/step - loss: 0.6377 - accuracy: 0.7577
# Epoch 2/2
# 161/161 [==============================] - 0s 2ms/step - loss: 0.4999 - accuracy: 0.7625
# 176/176 [==============================] - 0s 1ms/step
# Epoch 1/3
# 161/161 [==============================] - 1s 2ms/step - loss: 0.6559 - accuracy: 0.7434
# Epoch 2/3
# 161/161 [==============================] - 0s 2ms/step - loss: 0.5153 - accuracy: 0.8073
# Epoch 3/3
# 161/161 [==============================] - 0s 2ms/step - loss: 0.3959 - accuracy: 0.8410
# 176/176 [==============================] - 0s 1ms/step
# Epoch 1/3
# 161/161 [==============================] - 1s 2ms/step - loss: 0.6330 - accuracy: 0.7643
# Epoch 2/3
# 161/161 [==============================] - 0s 2ms/step - loss: 0.4667 - accuracy: 0.8048
# Epoch 3/3
# 161/161 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8048
# 176/176 [==============================] - 0s 1ms/step
# Epoch 1/3
# 161/161 [==============================] - 1s 2ms/step - loss: 0.6273 - accuracy: 0.7656
# Epoch 2/3
# 161/161 [==============================] - 0s 2ms/step - loss: 0.4798 - accuracy: 0.7669
# Epoch 3/3
# 161/161 [==============================] - 0s 2ms/step - loss: 0.4071 - accuracy: 0.7752
# 176/176 [==============================] - 0s 1ms/step
# Epoch 1/3
# 161/161 [==============================] - 1s 2ms/step - loss: 0.6365 - accuracy: 0.7595
# Epoch 2/3
# 161/161 [==============================] - 0s 2ms/step - loss: 0.5030 - accuracy: 0.7628
# Epoch 3/3
# 161/161 [==============================] - 0s 2ms/step - loss: 0.4180 - accuracy: 0.8011
# 176/176 [==============================] - 0s 2ms/step
# Epoch 1/2
# 563/563 [==============================] - 2s 2ms/step - loss: 0.4798 - accuracy: 0.7954
# Epoch 2/2
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2789 - accuracy: 0.8975

# %%
best_param = grid_search.best_params_
best_accuracy = grid_search.best_score_

# %%
best_param
# Out:
# {'batch_size': 20, 'epochs': 2, 'optimizer': 'adam'}

# %%
best_accuracy
# Out:
# 0.869232637901059
